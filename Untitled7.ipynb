# %%
import nltk
nltk.download('all')
from nltk.tokenize  import sent_tokenize
text = " hi?how ar eyou doing in this horrified and world of ratas"
print(sent_tokenize(text))
# Out:
#   File "<ipython-input-9-bacf483e6912>", line 1
#     pip install nltk
#               ^
# SyntaxError: invalid syntax

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
from nltk.tokenize  import sent_tokenize
text = "welcome to our university? hello mr local,?"
print(sent_tokenize(text))
# Out:
# ['welcome to our university?', 'hello mr local,?']

# %%
from nltk.util import bigrams,trigrams,ngrams
import nltk
ML = " gla university is the worst university in mathura and it even open it aniother branch of shit housery"
MLtokens  = nltk.word_tokenize(ML)
MLtokens
# ML_trigrams=list(nltk.trigrams(MLtokens))
# ML_trigrams
ML_trigrams  = list(nltk.trigrams(ML))
ML_ngrams = list(nltk.ngrams(ML,6))
ML_ngrams
# Out:
# [(' ', 'g', 'l', 'a', ' ', 'u'),
#  ('g', 'l', 'a', ' ', 'u', 'n'),
#  ('l', 'a', ' ', 'u', 'n', 'i'),
#  ('a', ' ', 'u', 'n', 'i', 'v'),
#  (' ', 'u', 'n', 'i', 'v', 'e'),
#  ('u', 'n', 'i', 'v', 'e', 'r'),
#  ('n', 'i', 'v', 'e', 'r', 's'),
#  ('i', 'v', 'e', 'r', 's', 'i'),
#  ('v', 'e', 'r', 's', 'i', 't'),
#  ('e', 'r', 's', 'i', 't', 'y'),
#  ('r', 's', 'i', 't', 'y', ' '),
#  ('s', 'i', 't', 'y', ' ', 'i'),
#  ('i', 't', 'y', ' ', 'i', 's'),
#  ('t', 'y', ' ', 'i', 's', ' '),
#  ('y', ' ', 'i', 's', ' ', 't'),
#  (' ', 'i', 's', ' ', 't', 'h'),
#  ('i', 's', ' ', 't', 'h', 'e'),
#  ('s', ' ', 't', 'h', 'e', ' '),
#  (' ', 't', 'h', 'e', ' ', 'w'),
#  ('t', 'h', 'e', ' ', 'w', 'o'),
#  ('h', 'e', ' ', 'w', 'o', 'r'),
#  ('e', ' ', 'w', 'o', 'r', 's'),
#  (' ', 'w', 'o', 'r', 's', 't'),
#  ('w', 'o', 'r', 's', 't', ' '),
#  ('o', 'r', 's', 't', ' ', 'u'),
#  ('r', 's', 't', ' ', 'u', 'n'),
#  ('s', 't', ' ', 'u', 'n', 'i'),
#  ('t', ' ', 'u', 'n', 'i', 'v'),
# ...
